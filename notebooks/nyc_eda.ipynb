# %%
import pandas as pd
from scipy import stats
from utils import create_connection, calculate_distance
import numpy as np
import pickle as pkl
import seaborn as sns
sns.set_theme()
#import geopandas as gpd
import matplotlib.pyplot as plt
import re

# %% [markdown]
# # Load the Data Set for all NYC boroughs

# %%
# Connect to the database
database = "../data/apartments.db"
conn = create_connection(database)
c = conn.cursor()

# %%
# Query the database to extract all listings from NYC
nyc_counties = [
    "Manhattan County",
    "Bronx County",
    "Brooklyn",
    "Queens County",
    "Staten Island"
]

query = f"""SELECT * FROM units
            JOIN properties
            USING (property_name)
            WHERE city_name IN {str(tuple(nyc_counties))};
"""

units = pd.read_sql_query(query, conn)
conn.close()
# Correct the borough data
units.rename(columns={'city_name':'borough'}, inplace=True)
units.borough = units.borough.str.replace("County", "").str.strip()

# Correct the dishwasher column to 1s and zeros only
units.dishwasher = np.where(units.dishwasher == 'True',
                            1,
                            units.dishwasher)
units.dishwasher = np.where(units.dishwasher == 'False',
                            0,
                            units.dishwasher)
units.head()
# Out:
#     property_name property_zipcode unit_id  rent beds baths sqft  \
# 0  The Brooklyner            11201   1-06K  4060    1     1  684
# 1  The Brooklyner            11201   1-09H  5122    2     2  976
# 2  The Brooklyner            11201   1-10K  4349    1     1  618
# 3  The Brooklyner            11201   1-11H  5195    2     2  976
# 4  The Brooklyner            11201   1-16K  3997    1     1  618
#
#   date_available date_scraped  fitness_center  ...  latitude  longitude  \
# 0     2022-05-06   2022-04-05               1  ...  40.69273  -73.98605
# 1     2022-04-05   2022-04-05               1  ...  40.69273  -73.98605
# 2     2022-04-05   2022-04-05               1  ...  40.69273  -73.98605
# 3     2022-04-05   2022-04-05               1  ...  40.69273  -73.98605
# 4     2022-04-05   2022-04-05               1  ...  40.69273  -73.98605
#
#         neighborhood  zipcode  \
# 0  Downtown Brooklyn    11201
# 1  Downtown Brooklyn    11201
# 2  Downtown Brooklyn    11201
# 3  Downtown Brooklyn    11201
# 4  Downtown Brooklyn    11201
#
#                                          description  \
# 0  NO BROKER FEES. The Brooklyner known as the ta...
# 1  NO BROKER FEES. The Brooklyner known as the ta...
# 2  NO BROKER FEES. The Brooklyner known as the ta...
# 3  NO BROKER FEES. The Brooklyner known as the ta...
# 4  NO BROKER FEES. The Brooklyner known as the ta...
#
#                                      unique_features   borough  year_built  \
# 0  Hardwood Floors, Self Guided Tours, Smoke Free...  Brooklyn        2010
# 1  Hardwood Floors, Self Guided Tours, Smoke Free...  Brooklyn        2010
# 2  Hardwood Floors, Self Guided Tours, Smoke Free...  Brooklyn        2010
# 3  Hardwood Floors, Self Guided Tours, Smoke Free...  Brooklyn        2010
# 4  Hardwood Floors, Self Guided Tours, Smoke Free...  Brooklyn        2010
#
#    dishwasher                                       property_url
# 0           1  https://www.apartments.com/the-brooklyner-broo...
# 1           1  https://www.apartments.com/the-brooklyner-broo...
# 2           1  https://www.apartments.com/the-brooklyner-broo...
# 3           1  https://www.apartments.com/the-brooklyner-broo...
# 4           1  https://www.apartments.com/the-brooklyner-broo...
#
# [5 rows x 32 columns]

# %%
# Fix listings that contain both in unit washer/dryer and laundry facilities
# If there's an in_unit_washer_dryer then laundry facilities should be set to zero 

units.laundry_facilities = np.where(units.in_unit_washer_dryer == 1,
                                    0,
                                    units.laundry_facilities)

# %%
units.dtypes
# Out:
# property_name           object
# property_zipcode        object
# unit_id                 object
# rent                    object
# beds                    object
# baths                   object
# sqft                    object
# date_available          object
# date_scraped            object
# fitness_center           int64
# air_conditioning         int64
# in_unit_washer_dryer     int64
# laundry_facilities       int64
# car_charging             int64
# roof                     int64
# concierge                int64
# pool                     int64
# elevator                 int64
# garage                   int64
# dogs_allowed             int64
# cats_allowed             int64
# income_restrictions      int64
# latitude                object
# longitude               object
# neighborhood            object
# zipcode                 object
# description             object
# unique_features         object
# borough                 object
# year_built              object
# dishwasher              object
# property_url            object
# dtype: object

# %%
pd.concat([units.isnull().sum(),units.eq('').sum()],keys=['Nulls','Empty'],axis=1)
# Out:
#                       Nulls  Empty
# property_name             0      0
# property_zipcode          0      0
# unit_id                   0      0
# rent                      0      9
# beds                      0      0
# baths                     0      0
# sqft                      0   1301
# date_available            0      0
# date_scraped              0      0
# fitness_center            0      0
# air_conditioning          0      0
# in_unit_washer_dryer      0      0
# laundry_facilities        0      0
# car_charging              0      0
# roof                      0      0
# concierge                 0      0
# pool                      0      0
# elevator                  0      0
# garage                    0      0
# dogs_allowed              0      0
# cats_allowed              0      0
# income_restrictions       0      0
# latitude                  0      0
# longitude                 0      0
# neighborhood              0      0
# zipcode                   0      0
# description               0      0
# unique_features           0   3305
# borough                   0      0
# year_built                0      0
# dishwasher                0      0
# property_url              0      0

# %%
# Remove all units without square feet or rent values
# It's possible to impute these missing values
# but likely will skew any results that are generated
units = units[units.sqft != '']
units = units[units.rent != '']

# %%
units.rent=units.rent.astype(float)
units.sqft=units.sqft.astype(float)
units.beds=units.beds.astype(int)
units.baths=units.baths.astype(float)
units.latitude=units.latitude.astype(float)
units.longitude=units.longitude.astype(float)
units.dishwasher=units.dishwasher.astype(int)

# %% [markdown]
# # Initial exploration

# %%
# Plotting the location of all the apartments
sns.set_style("ticks")
fig = plt.gcf()
scaler = abs((units.latitude.max()-units.latitude.min())/(units.longitude.max()-units.longitude.min()))
fig.set_size_inches(15, 15*scaler)

sns.scatterplot(data=units, x='longitude', y='latitude', hue = 'borough',palette='colorblind')
# Out:
# <AxesSubplot:xlabel='longitude', ylabel='latitude'>

# %% [markdown]
# ### Checking the data for outliers and bad data

# %%
# Descriptive stats based on setting a specific target column
def descriptive_stats(target,df):
    average = df.groupby('beds', as_index=True)[target].mean()
    ci_5 = df.groupby('beds', as_index=True)[target].quantile(0.05)    #5th Percentile
    ci_95 = df.groupby('beds', as_index=True)[target].quantile(0.95)   #95th Percentile
    minimum= df.groupby('beds', as_index=True)[target].min()
    maximum = df.groupby('beds', as_index=True)[target].max()
    std = df.groupby('beds', as_index=True)[target].std()
    num = df.groupby('beds', as_index=True)[target].count()
    
    stats_df = pd.DataFrame({f'Average {target}':average, 
                            '5th Percentile':ci_5,
                            '95th Percentile':ci_95,
                            'Minimum':minimum, 
                            'Maximum':maximum,
                            'Standard Deviation':std,
                            'Number of Units': num})
    
    stats_df.reset_index(inplace=True)
    return stats_df

# %%
# Add a price/sqft column that will be useful for visualization and detecting outliers
units['price/sqft'] = units.rent / units.sqft

# %%
# Get the descriptive stats for the price/sqft column
descriptive_stats('price/sqft',units)
# Out:
#    beds  Average price/sqft  5th Percentile  95th Percentile   Minimum  \
# 0     0           12.245065        2.542254        15.000000  1.111111
# 1     1           25.729248        1.949000         8.094819  0.519500
# 2     2           20.724236        2.001401         7.076190  0.555556
# 3     3           12.850682        1.725949         7.478107  0.626959
# 4     4           33.915657        1.932507         6.871227  0.295730
# 5     5            3.080949        1.508928         5.281250  0.360036
# 6     6            3.660153        2.272153         6.975882  1.986922
#
#        Maximum  Standard Deviation  Number of Units
# 0  2100.000000          103.935769              407
# 1  3850.000000          241.929036              817
# 2  5900.000000          280.377069              875
# 3  4799.000000          194.771262              632
# 4  6495.000000          442.704692              215
# 5     5.281250            1.137664               36
# 6     9.376471            2.182752                9

# %%
# Get the descriptive stats for the rent column
descriptive_stats('rent',units)
# Out:
#    beds  Average rent  5th Percentile  95th Percentile  Minimum  Maximum  \
# 0     0   2806.490172         1354.80          4531.50   1050.0   8000.0
# 1     1   3158.505508         1600.00          5502.20    700.0   8000.0
# 2     2   3594.904571         1995.00          7618.60   1500.0  12000.0
# 3     3   3821.359968         2270.35          7451.55    925.0  23250.0
# 4     4   4450.558140         2549.70          7823.50   1300.0  20775.0
# 5     5   5017.027778         3100.00          8462.50   2850.0  11000.0
# 6     6   5146.000000         1890.00          7942.00   1350.0   7970.0
#
#    Standard Deviation  Number of Units
# 0         1136.218474              407
# 1         1336.547398              817
# 2         1906.269508              875
# 3         2229.905505              632
# 4         2359.380757              215
# 5         2045.532700               36
# 6         2162.659878                9

# %%
# Get the descriptive stats for the sqft column
descriptive_stats('sqft',units)
# Out:
#    beds  Average sqft  5th Percentile  95th Percentile  Minimum  Maximum  \
# 0     0    507.953317           101.3           921.00      1.0   7200.0
# 1     1    741.169523           500.0          1000.00      1.0  10000.0
# 2     2    943.567429           603.5          1350.00      1.0   3600.0
# 3     3   1130.002373           800.0          1909.45      1.0   3800.0
# 4     4   1325.576744           835.0          2039.30      1.0   9999.0
# 5     5   2098.472222          1200.0          6368.25   1200.0   9999.0
# 6     6   1636.222222           580.0          3105.60    400.0   3976.0
#
#    Standard Deviation  Number of Units
# 0          404.655615              407
# 1          398.800724              817
# 2          306.502464              875
# 3          374.790755              632
# 4          971.536918              215
# 5         2095.378609               36
# 6         1007.848423                9

# %%
# Drop the 5 and 6 bedroom units since they make up a small portion of the dataset
units = units[units.beds < 5]

# %%
units[units.sqft < 51]
# Out:
#                 property_name property_zipcode  unit_id    rent  beds  baths  \
# 464   238 Fort Washington Ave            10032       41  2995.0     3    1.0
# 472      175 West 87th Street            10024  175-17A  5900.0     2    2.0
# 481             529 Broome St            10013        3  4244.0     2    1.0
# 543           121 Madison Ave            10016       19  6495.0     4    2.0
# 544             240 W 15th St            10011        3  2600.0     1    1.0
# 605             159 W 72nd St            10023       10  3850.0     1    1.0
# 708            656 W 171st St            10032       5D  2395.0     2    1.0
# 709            656 W 171st St            10032       5F  1995.0     1    1.0
# 1296           618 W 142nd St            10031       1C  2195.0     1    1.0
# 1299           725 W 172nd St            10032       67  1895.0     1    1.0
# 1431            321 W 80th St            10024        5  3300.0     1    1.0
# 1481            201 E 27th St            10016       10  2100.0     0    1.0
# 1482            201 E 27th St            10016        4  2700.0     1    1.0
# 1510          128 Thompson St            10012       22  4799.0     3    1.5
# 1511          128 Thompson St            10012        9  3999.0     2    1.0
# 2306        48-16 46th Street            11377    1 Bed  1850.0     1    1.0
# 3369               Willoughby            11201      17A  3392.0     0    0.0
# 3370               Willoughby            11201      17M  4085.0     1    1.0
# 3371               Willoughby            11201      18B  3369.0     0    0.0
# 3372               Willoughby            11201      19D  4062.0     1    1.0
# 3373               Willoughby            11201      19S  4292.0     1    1.0
# 3374               Willoughby            11201      21E  7662.0     2    2.0
# 3375               Willoughby            11201       3U  3138.0     0    0.0
#
#       sqft date_available date_scraped  fitness_center  ...  longitude  \
# 464    3.0     2022-04-04   2022-04-04               0  ...  -73.94155
# 472    1.0     2022-04-05   2022-04-05               1  ...  -73.97387
# 481    1.0     2022-04-05   2022-04-05               0  ...  -74.00423
# 543    1.0     2022-04-04   2022-04-04               0  ...  -73.98450
# 544    1.0     2022-04-05   2022-04-05               0  ...  -74.00110
# 605    1.0     2022-04-04   2022-04-04               0  ...  -73.98064
# 708    5.0     2022-04-04   2022-04-04               0  ...  -73.94064
# 709    5.0     2022-04-04   2022-04-04               0  ...  -73.94064
# 1296   1.0     2022-04-04   2022-04-04               0  ...  -73.95318
# 1299   6.0     2022-04-04   2022-04-04               0  ...  -73.94186
# 1431   1.0     2022-04-04   2022-04-04               0  ...  -73.98159
# 1481   1.0     2022-04-04   2022-04-04               0  ...  -73.98099
# 1482   1.0     2022-04-04   2022-04-04               0  ...  -73.98099
# 1510   1.0     2022-04-04   2022-04-04               0  ...  -74.00111
# 1511   1.0     2022-04-04   2022-04-04               0  ...  -74.00111
# 2306   1.0     2022-04-05   2022-04-05               1  ...  -73.91974
# 3369  50.0     2022-04-05   2022-04-05               1  ...  -73.97940
# 3370  50.0     2022-04-05   2022-04-05               1  ...  -73.97940
# 3371  50.0     2022-04-05   2022-04-05               1  ...  -73.97940
# 3372  50.0     2022-04-05   2022-04-05               1  ...  -73.97940
# 3373  50.0     2022-04-05   2022-04-05               1  ...  -73.97940
# 3374  50.0     2022-04-15   2022-04-05               1  ...  -73.97940
# 3375  50.0     2022-04-05   2022-04-05               1  ...  -73.97940
#
#              neighborhood  zipcode  \
# 464    Washington Heights    10032
# 472       Upper West Side    10024
# 481                  SoHo    10013
# 543              Kips Bay    10016
# 544               Chelsea    10011
# 605       Upper West Side    10023
# 708    Washington Heights    10032
# 709    Washington Heights    10032
# 1296     Hamilton Heights    10031
# 1299   Washington Heights    10032
# 1431      Upper West Side    10024
# 1481             Kips Bay    10016
# 1482             Kips Bay    10016
# 1510                 SoHo    10012
# 1511                 SoHo    10012
# 2306  Northwestern Queens    11377
# 3369          Fort Greene    11201
# 3370          Fort Greene    11201
# 3371          Fort Greene    11201
# 3372          Fort Greene    11201
# 3373          Fort Greene    11201
# 3374          Fort Greene    11201
# 3375          Fort Greene    11201
#
#                                             description  \
# 464   NO BROKER FEE!!True 3bed steps to COLUMBIA Med...
# 472   Elegance meets cosmopolitan flair at 175 West ...
# 481   Great  deal in Soho!large 2 bedrooms in great ...
# 543   This spacious convertible 4 bedroom apartment ...
# 544   Sunny 1 bedroom on quiet street with dishwashe...
# 605   Newly renovated huge 1 bed in prime Upper West...
# 708   Beautifully Renovated KING  1 BEDSteps to Colu...
# 709   Beautifully Renovated KING  1 BEDSteps to Colu...
# 1296  large 1 brEntrance Foyertons of Closet spaceSe...
# 1299  NO FEEBright and Sunny two bedroomSteps to COL...
# 1431  Newly Renovated 1 bedroom in beautiful walk up...
# 1481  * PRIME LOCATION * LARGE 1 BED * NEW KITCHEN *...
# 1482  * PRIME LOCATION * LARGE 1 BED * NEW KITCHEN *...
# 1510  Amazing large 2 bed in prime SOHO.Apartment fe...
# 1511  Amazing large 2 bed in prime SOHO.Apartment fe...
# 2306  This quaint 4-story, 20-unit property has a br...
# 3369  BROOKLYNS MOST DYNAMIC NEW RESIDENCEThe Willou...
# 3370  BROOKLYNS MOST DYNAMIC NEW RESIDENCEThe Willou...
# 3371  BROOKLYNS MOST DYNAMIC NEW RESIDENCEThe Willou...
# 3372  BROOKLYNS MOST DYNAMIC NEW RESIDENCEThe Willou...
# 3373  BROOKLYNS MOST DYNAMIC NEW RESIDENCEThe Willou...
# 3374  BROOKLYNS MOST DYNAMIC NEW RESIDENCEThe Willou...
# 3375  BROOKLYNS MOST DYNAMIC NEW RESIDENCEThe Willou...
#
#                             unique_features    borough  year_built  \
# 464                                          Manhattan        NULL
# 472   Bike Storage, Courtyard, Pet Friendly  Manhattan        1975
# 481                                          Manhattan        NULL
# 543                                          Manhattan        NULL
# 544                                          Manhattan        NULL
# 605                                          Manhattan        NULL
# 708                                          Manhattan        NULL
# 709                                          Manhattan        NULL
# 1296                                         Manhattan        NULL
# 1299                                         Manhattan        NULL
# 1431                                         Manhattan        NULL
# 1481                                         Manhattan        NULL
# 1482                                         Manhattan        NULL
# 1510                                         Manhattan        NULL
# 1511                                         Manhattan        NULL
# 2306          Hardwood Floors, Refrigerator     Queens        1936
# 3369                                          Brooklyn        2021
# 3370                                          Brooklyn        2021
# 3371                                          Brooklyn        2021
# 3372                                          Brooklyn        2021
# 3373                                          Brooklyn        2021
# 3374                                          Brooklyn        2021
# 3375                                          Brooklyn        2021
#
#       dishwasher                                       property_url  \
# 464            0  https://www.apartments.com/238-fort-washington...
# 472            1  https://www.apartments.com/175-west-87th-stree...
# 481            0  https://www.apartments.com/529-broome-st-new-y...
# 543            1  https://www.apartments.com/121-madison-ave-new...
# 544            1  https://www.apartments.com/240-w-15th-st-new-y...
# 605            0  https://www.apartments.com/159-w-72nd-st-new-y...
# 708            0  https://www.apartments.com/656-w-171st-st-new-...
# 709            0  https://www.apartments.com/656-w-171st-st-new-...
# 1296           0  https://www.apartments.com/618-w-142nd-st-new-...
# 1299           0  https://www.apartments.com/725-w-172nd-st-new-...
# 1431           1  https://www.apartments.com/321-w-80th-st-new-y...
# 1481           0  https://www.apartments.com/201-e-27th-st-new-y...
# 1482           0  https://www.apartments.com/201-e-27th-st-new-y...
# 1510           0  https://www.apartments.com/128-thompson-st-new...
# 1511           0  https://www.apartments.com/128-thompson-st-new...
# 2306           1  https://www.apartments.com/48-16-46th-street-f...
# 3369           1  https://www.apartments.com/willoughby-brooklyn...
# 3370           1  https://www.apartments.com/willoughby-brooklyn...
# 3371           1  https://www.apartments.com/willoughby-brooklyn...
# 3372           1  https://www.apartments.com/willoughby-brooklyn...
# 3373           1  https://www.apartments.com/willoughby-brooklyn...
# 3374           1  https://www.apartments.com/willoughby-brooklyn...
# 3375           1  https://www.apartments.com/willoughby-brooklyn...
#
#        price/sqft
# 464    998.333333
# 472   5900.000000
# 481   4244.000000
# 543   6495.000000
# 544   2600.000000
# 605   3850.000000
# 708    479.000000
# 709    399.000000
# 1296  2195.000000
# 1299   315.833333
# 1431  3300.000000
# 1481  2100.000000
# 1482  2700.000000
# 1510  4799.000000
# 1511  3999.000000
# 2306  1850.000000
# 3369    67.840000
# 3370    81.700000
# 3371    67.380000
# 3372    81.240000
# 3373    85.840000
# 3374   153.240000
# 3375    62.760000
#
# [23 rows x 33 columns]

# %% [markdown]
# None of these units appear to be listings that can represent realistic expectations. As noted before, it is possible to impute these values but we will proceed for now with removing them. There are many factors that can drive the size of the unit beyond comparing to what it should be given the rent and number of bedrooms.

# %%
# Drop all units less than 50sqft
units = units[units.sqft > 51]

# %%
units[units.sqft > 4000]
# Out:
#        property_name property_zipcode                 unit_id    rent  beds  \
# 665      22 Park Ave            10016                    005C  5195.0     1
# 1226    895 Park Ave            10075            895 Park Ave  8000.0     0
# 2834  445 Deisius St            10312  1st Floor and Basement  3500.0     4
# 2894     84 Newel St            11222                      2L  2957.0     4
# 3867  551 Graham Ave            11222                      3L  3800.0     4
#
#       baths     sqft date_available date_scraped  fitness_center  ...  \
# 665     1.0  10000.0     2022-04-05   2022-04-05               1  ...
# 1226    1.0   7200.0     2022-04-05   2022-04-05               1  ...
# 2834    3.0   4700.0     2022-04-05   2022-04-05               0  ...
# 2894    1.0   9999.0     2022-04-05   2022-04-05               0  ...
# 3867    2.0   9999.0     2022-04-05   2022-04-05               0  ...
#
#       longitude     neighborhood  zipcode  \
# 665   -73.98088      Murray Hill    10016
# 1226  -73.96035  Upper East Side    10075
# 2834  -74.19103     Prince's Bay    10312
# 2894  -73.94743         Brooklyn    11222
# 3867  -73.94732       Greenpoint    11222
#
#                                             description  unique_features  \
# 665   This building combines the charisma of old New...
# 1226  Upper East Side, 1.0 Bathroom, 7.0 Rooms, Heal...
# 2834  Brand new construction with stainless steel ap...
# 2894  NO FEE! Affordable, true 4BR on a quiet block ...
# 3867  NO FEE! True 4BR/2BA on Graham Ave, 2 blocks f...
#
#             borough  year_built  dishwasher  \
# 665       Manhattan        NULL           0
# 1226      Manhattan        NULL           0
# 2834  Staten Island        NULL           1
# 2894       Brooklyn        NULL           0
# 3867       Brooklyn        NULL           0
#
#                                            property_url  price/sqft
# 665   https://www.apartments.com/22-park-ave-new-yor...    0.519500
# 1226  https://www.apartments.com/895-park-ave-new-yo...    1.111111
# 2834  https://www.apartments.com/445-deisius-st-stat...    0.744681
# 2894  https://www.apartments.com/84-newel-st-brookly...    0.295730
# 3867  https://www.apartments.com/551-graham-ave-broo...    0.380038
#
# [5 rows x 33 columns]

# %%
# Drop all units with more than 5,000 square feet
units = units[units.sqft < 5000]

# %%
#Distribution of the rent column
sns.displot(units.rent)
fig = plt.figure()
res = stats.probplot(units.rent, plot=plt)

# %%
#Distribution of the sqft column
sns.displot(units.sqft)
fig = plt.figure()
res = stats.probplot(units.sqft, plot=plt)

# %%
# Detecting possible outliers with standard deviation and IQR 
def outlier_detection(target,df_input):
    
    # Adjust the distributions since they are not normal
    if target == 'rent':
        df_input.loc[:, 'rent'] = np.log(df_input.rent)
    elif target == 'sqft':
        df_input.loc[:, 'sqft'] = np.log(df_input.sqft)
    
    # Boundary zones
    average = df_input.groupby('beds', as_index=True)[target].mean()
    std = df_input.groupby('beds', as_index=True)[target].std()
    upper_limit = average + 3*std
    lower_limit = average - 3*std
    
    # Quartile Range
    iqr_25 = df_input.groupby('beds', as_index=True)[target].quantile(0.25)    
    iqr_75 = df_input.groupby('beds', as_index=True)[target].quantile(0.75)   
    iqr = iqr_75 - iqr_25
    iqr_upper = iqr_75 + iqr
    iqr_lower = iqr_25 - iqr
    
    # Set the conditions for upper limit
    cond1 = df_input[target] > df_input.beds.map(upper_limit)
    cond2 = df_input[target] > df_input.beds.map(iqr_upper)
    
    # Set the conditions for lower limit
    cond3 = df_input[target] < df_input.beds.map(lower_limit)
    cond4 = df_input[target] < df_input.beds.map(iqr_lower)

    outlier_df = df_input[(cond1 & cond2)]
    
    # Take the exponential to revert back to the original data condition
    if target == 'rent':
        outlier_df.loc[:,target] = np.exp(outlier_df.loc[:,target])
    elif target == 'sqft':
        outlier_df.loc[:,target] = np.exp(outlier_df.loc[:,target])
        
    # Filter out any income restriction units
    outlier_df = outlier_df[outlier_df.income_restrictions != 1]
    
    #stats_df.reset_index(inplace=True)
    return outlier_df

# %%
# Check for additional outliers in the rent column
outliers = pd.concat([outlier_detection('rent', units.copy()),outlier_detection('rent', units.copy())]).drop_duplicates()
outliers.head(10)
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
#                        property_name property_zipcode                 unit_id  \
# 232                    Anagram Nomad            10016  3 Bedroom / 3 Bathroom
# 408              101 West End Avenue            10023                     09M
# 414              101 West End Avenue            10023                     18F
# 638                        The Aldyn            10069                    0707
# 787                    165 E 66th St            10065                      9F
# 864  Waterline Square Luxury Rentals            10069     One Waterline #2103
# 865  Waterline Square Luxury Rentals            10069     One Waterline #2204
# 866  Waterline Square Luxury Rentals            10069   Three Waterline #1708
# 869  Waterline Square Luxury Rentals            10069   Three Waterline #2901
# 871  Waterline Square Luxury Rentals            10069   Three Waterline #3202
#
#         rent  beds  baths    sqft date_available date_scraped  fitness_center  \
# 232  14748.0     3    3.0  1618.0     2022-06-04   2022-04-05               1
# 408  11812.0     3    3.0  1772.0     2022-04-15   2022-04-05               1
# 414  12035.0     3    3.0  1435.0     2022-04-05   2022-04-05               1
# 638  13625.0     3    3.0  1726.0     2022-05-23   2022-04-05               0
# 787  12000.0     3    3.0  1600.0     2022-04-04   2022-04-04               0
# 864  17575.0     3    2.5  1557.0     2022-04-05   2022-04-05               1
# 865  20722.0     4    3.5  2170.0     2022-04-05   2022-04-05               1
# 866  20775.0     4    3.5  1966.0     2022-04-05   2022-04-05               1
# 869  23250.0     3    3.5  2026.0     2022-04-05   2022-04-05               1
# 871  22125.0     3    3.0  1823.0     2022-04-05   2022-04-05               1
#
#      ...  longitude    neighborhood  zipcode  \
# 232  ...  -73.98619           NoMad    10016
# 408  ...  -73.98835  Lincoln Square    10023
# 414  ...  -73.98835  Lincoln Square    10023
# 638  ...  -73.99084  Lincoln Square    10069
# 787  ...  -73.96330        New York    10065
# 864  ...  -73.99260  Lincoln Square    10069
# 865  ...  -73.99260  Lincoln Square    10069
# 866  ...  -73.99260  Lincoln Square    10069
# 869  ...  -73.99260  Lincoln Square    10069
# 871  ...  -73.99260  Lincoln Square    10069
#
#                                            description  \
# 232  Now offering flexible touring options includin...
# 408  NO BROKER FEES At 101 West End Apartments, you...
# 414  NO BROKER FEES At 101 West End Apartments, you...
# 638  Welcome home to The Aldyn, where the best of M...
# 787  Hanley New York is a luxury doorman building l...
# 864  Schedule your virtual appointment today!Spanni...
# 865  Schedule your virtual appointment today!Spanni...
# 866  Schedule your virtual appointment today!Spanni...
# 869  Schedule your virtual appointment today!Spanni...
# 871  Schedule your virtual appointment today!Spanni...
#
#                                        unique_features    borough  year_built  \
# 232  24-Hour-Attended Lobby, Balcon, Balcony, Bicyc...  Manhattan        1998
# 408  24-Hour Concierge, Additional Storage, Alcove ...  Manhattan        1999
# 414  24-Hour Concierge, Additional Storage, Alcove ...  Manhattan        1999
# 638  38 Rock Climbing Wall, 40,000 Sq Ft The Wright...  Manhattan        2010
# 787                                                     Manhattan        NULL
# 864  30-Foot Rock Climbing Wall, Art Studio, Bowlin...  Manhattan        2019
# 865  30-Foot Rock Climbing Wall, Art Studio, Bowlin...  Manhattan        2019
# 866  30-Foot Rock Climbing Wall, Art Studio, Bowlin...  Manhattan        2019
# 869  30-Foot Rock Climbing Wall, Art Studio, Bowlin...  Manhattan        2019
# 871  30-Foot Rock Climbing Wall, Art Studio, Bowlin...  Manhattan        2019
#
#      dishwasher                                       property_url  price/sqft
# 232           1  https://www.apartments.com/anagram-nomad-new-y...    9.114957
# 408           1  https://www.apartments.com/101-west-end-avenue...    6.665914
# 414           1  https://www.apartments.com/101-west-end-avenue...    8.386760
# 638           1  https://www.apartments.com/the-aldyn-new-york-...    7.893975
# 787           1  https://www.apartments.com/165-e-66th-st-new-y...    7.500000
# 864           1  https://www.apartments.com/waterline-square-lu...   11.287733
# 865           1  https://www.apartments.com/waterline-square-lu...    9.549309
# 866           1  https://www.apartments.com/waterline-square-lu...   10.567141
# 869           1  https://www.apartments.com/waterline-square-lu...   11.475814
# 871           1  https://www.apartments.com/waterline-square-lu...   12.136588
#
# [10 rows x 33 columns]

# %%
# Drop all the extreme outliers as they represent less than 1% of the data (3+ standard deviations away)
units = units[~units.index.isin(outliers.index)]

# %%
# Check for additional outliers in the sqft column
outliers = pd.concat([outlier_detection('sqft', units.copy()),outlier_detection('sqft', units.copy())]).drop_duplicates()
outliers.head(10)
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
#           property_name property_zipcode                 unit_id    rent  \
# 1452  281 Edgecombe Ave            10031                      4A  2235.0
# 2344     11630 219th St            11411                      #1  2000.0
# 2402      8540 102nd St            11418                       1  1750.0
# 2663     85-11 150th St            11435               2nd Floor  2000.0
# 2834     445 Deisius St            10312  1st Floor and Basement  3500.0
# 2916      976 Fulton St            11238        976 Fulton St 5B  3241.0
# 3056    1893 Pacific St            11233                       1  2750.0
# 3057    1893 Pacific St            11233                       2  2750.0
# 3175     2680 Fulton St            11207          2680 Fulton St  2000.0
# 3179    9502 Foster Ave            11236         9502 Foster Ave  1800.0
#
#       beds  baths    sqft date_available date_scraped  fitness_center  ...  \
# 1452     2    2.0  2235.0     2022-04-05   2022-04-05               0  ...
# 2344     2    1.0  3600.0     2022-04-05   2022-04-05               0  ...
# 2402     1    1.0  1800.0     2022-04-05   2022-04-05               0  ...
# 2663     3    1.0  3190.0     2022-04-05   2022-04-05               0  ...
# 2834     4    3.0  4700.0     2022-04-05   2022-04-05               0  ...
# 2916     1    1.0  3241.0     2022-04-05   2022-04-05               1  ...
# 3056     1    1.0  1640.0     2022-04-05   2022-04-05               0  ...
# 3057     1    1.0  1650.0     2022-04-05   2022-04-05               0  ...
# 3175     2    1.0  2880.0     2022-04-05   2022-04-05               1  ...
# 3179     1    1.0  3020.0     2022-04-05   2022-04-05               1  ...
#
#       longitude      neighborhood  zipcode  \
# 1452  -73.94359        Sugar Hill    10031
# 2344  -73.74086  Southeast Queens    11411
# 2402  -73.84649  Southeast Queens    11418
# 2663  -73.80873  Southeast Queens    11435
# 2834  -74.19103      Prince's Bay    10312
# 2916  -73.96184      Clinton Hill    11238
# 3056  -73.92621        Weeksville    11233
# 3057  -73.92621        Weeksville    11233
# 3175  -73.89568     Cypress Hills    11207
# 3179  -73.90716          Canarsie    11236
#
#                                             description  unique_features  \
# 1452  Enjoy New York City living at 281 Edgecombe Av...
# 2344  Walking distance to transportation, schools an...
# 2402  Perfect Opportunity ! On a lovely tree lined b...
# 2663  HUGE THREE (3) bedroom apartment for rent on 2...
# 2834  Brand new construction with stainless steel ap...
# 2916  Beautiful 7 Storie elevator building with stun...
# 3056  BRAND NEW FURNISHED HUGE 1BEDROOM/ 1 BATHROOM ...
# 3057  BRAND NEW FURNISHED HUGE 1BEDROOM/ 1 BATHROOM ...
# 3175  Beautiful huge newly renovated 2 bedrooms apar...
# 3179  Canarsie1 Bedroom apartment with EIK , Living ...
#
#             borough  year_built  dishwasher  \
# 1452      Manhattan        1920           0
# 2344         Queens        NULL           0
# 2402         Queens        NULL           1
# 2663         Queens        NULL           0
# 2834  Staten Island        NULL           1
# 2916       Brooklyn        2016           1
# 3056       Brooklyn        NULL           1
# 3057       Brooklyn        NULL           1
# 3175       Brooklyn        NULL           1
# 3179       Brooklyn        NULL           1
#
#                                            property_url  price/sqft
# 1452  https://www.apartments.com/281-edgecombe-ave-n...    1.000000
# 2344  https://www.apartments.com/11630-219th-st-camb...    0.555556
# 2402  https://www.apartments.com/8540-102nd-st-richm...    0.972222
# 2663  https://www.apartments.com/85-11-150th-st-quee...    0.626959
# 2834  https://www.apartments.com/445-deisius-st-stat...    0.744681
# 2916  https://www.apartments.com/976-fulton-st-brook...    1.000000
# 3056  https://www.apartments.com/1893-pacific-st-bro...    1.676829
# 3057  https://www.apartments.com/1893-pacific-st-bro...    1.666667
# 3175  https://www.apartments.com/2680-fulton-st-broo...    0.694444
# 3179  https://www.apartments.com/9502-foster-ave-bro...    0.596026
#
# [10 rows x 33 columns]

# %%
# Check for additional outliers in the price/sqft column
outliers = pd.concat([outlier_detection('price/sqft', units.copy()),outlier_detection('price/sqft', units.copy())]).drop_duplicates()
outliers.head(10)
# Out:
#                                      property_name property_zipcode unit_id  \
# 76                                    31 E 30th St            10016      3C
# 106                           1628 2nd Ave Unit 4N            10028      4N
# 198                                  120 E 10th St            10003       4
# 299                           622 East 11th Street            10009      05
# 343                               126 Rivington St            10002      4A
# 697                                  629 W 57th St            10019    2354
# 842                                        View 34            10016    S23H
# 959                                  315 N End Ave            10282      7S
# 962                            543 East 5th Street            10009      01
# 964  FOUND Study Upper East Side - Student Housing            10075       2
#
#        rent  beds  baths    sqft date_available date_scraped  fitness_center  \
# 76   3200.0     2    1.0   300.0     2022-04-04   2022-04-04               0
# 106  4500.0     0    1.0   100.0     2022-04-05   2022-04-05               0
# 198  8450.0     4    2.0   900.0     2022-07-01   2022-04-04               0
# 299  2750.0     2    2.0   300.0     2022-06-01   2022-04-05               1
# 343  4999.0     3    1.5   100.0     2022-04-05   2022-04-05               0
# 697  9995.0     2    2.0  1000.0     2022-04-04   2022-04-04               0
# 842  5869.0     1    1.0   587.0     2022-04-09   2022-04-04               1
# 959  8200.0     2    2.0   900.0     2022-04-04   2022-04-04               1
# 962  3550.0     2    2.0   300.0     2022-04-05   2022-04-05               1
# 964  1500.0     1    1.0   132.0     2022-04-05   2022-04-05               0
#
#      ...  longitude        neighborhood  zipcode  \
# 76   ...  -73.98405            Kips Bay    10016
# 106  ...  -73.95226     Upper East Side    10028
# 198  ...  -73.98817        East Village    10003
# 299  ...  -73.97860       Alphabet City    10009
# 343  ...  -73.98702     Lower East Side    10002
# 697  ...  -73.99215      Lincoln Square    10019
# 842  ...  -73.97257         Murray Hill    10016
# 959  ...  -74.00597  Downtown Manhattan    10282
# 962  ...  -73.98238       Alphabet City    10009
# 964  ...  -73.95369          Lenox Hill    10075
#
#                                            description  \
# 76   Location, location, location!Very close to Ame...
# 106  (*Unfurnished or Furnished*)****SuN-Drenched S...
# 198  120 E 10th St is an apartment located inManhat...
# 299  Want to live in a NYC apartment building that ...
# 343  Fantastic apartment features hardwood floors, ...
# 697  Features    Laundry in Unit    Private Outdoor...
# 842  View 34 is the new destination for upscale liv...
# 959  Luxurious 2 BR / 2 BA Apartment located in Bea...
# 962  543 East 5th Street is a 6 story walk up that ...
# 964  FOUND Study Upper East Side offers fully furni...
#
#                                        unique_features    borough  year_built  \
# 76                                                      Manhattan        NULL
# 106                                                     Manhattan        NULL
# 198                                                     Manhattan        NULL
# 299  Citi Bike Station Nearby, Dishwasher*, Duplex*...  Manhattan        1900
# 343                                                     Manhattan        NULL
# 697                                                     Manhattan        NULL
# 842  Bicycle storage room, Bookcase divider, Build ...  Manhattan        1985
# 959                                                     Manhattan        NULL
# 962  Citi Bike Station Nearby, Decorative Fireplace...  Manhattan        1900
# 964                                    Student Housing  Manhattan        1920
#
#      dishwasher                                       property_url  price/sqft
# 76            0  https://www.apartments.com/31-e-30th-st-new-yo...   10.666667
# 106           1  https://www.apartments.com/1628-2nd-ave-new-yo...   45.000000
# 198           0  https://www.apartments.com/120-e-10th-st-new-y...    9.388889
# 299           1  https://www.apartments.com/622-east-11th-stree...    9.166667
# 343           0  https://www.apartments.com/126-rivington-st-ne...   49.990000
# 697           1  https://www.apartments.com/629-w-57th-st-new-y...    9.995000
# 842           0  https://www.apartments.com/view-34-new-york-ny...    9.998296
# 959           1  https://www.apartments.com/315-n-end-ave-new-y...    9.111111
# 962           1  https://www.apartments.com/543-east-5th-street...   11.833333
# 964           1  https://www.apartments.com/found-study-upper-e...   11.363636
#
# [10 rows x 33 columns]

# %%
# Drop all the extreme outliers as they represent less than 1% of the data (3+ standard deviations away)
units = units[~units.index.isin(outliers.index)]

# %% [markdown]
# ### Add in additional location featurs
# * Distance to wall street and midtown manhattan
# * Distance to nearest MTA stop
# * Neighbourhood cluster id (to replace zipcode and neighborhood)

# %%
# Load MTA Stop locations and clean to useable form
# Data comes in the form of: POINT(LAT LONG)
mta_stops = pd.read_csv('../data/external/nyc/mta_locations.csv')['the_geom']
mta_stops.replace('[POINT()]', '',regex=True, inplace=True)
mta_stops = mta_stops.str.strip()
mta_stops = pd.DataFrame(mta_stops.str.split(' ').to_list())
mta_stops.rename(columns={0:'lon', 1: 'lat'}, inplace=True)
mta_stops.lat=mta_stops.lat.astype(float)
mta_stops.lon=mta_stops.lon.astype(float)
mta_stops.drop_duplicates(inplace=True)
mta_stops.head()
# Out:
#          lon        lat
# 0 -73.868356  40.849169
# 1 -73.868213  40.849128
# 2 -73.873499  40.841223
# 3 -73.872892  40.841453
# 4 -73.879623  40.840815

# %%
# Define the locations of wall street and midtown
midtown = {'lat': 40.752148801459604, 'lon': -73.98749979654413}
wall_street = {'lat': 40.70773721622127, 'lon': -74.0101688916038}

# %%
# Calculate the nearest MTA stop for each listing
units['dist_transit']=units.apply(lambda row: calculate_distance(row.latitude, row.longitude, mta_stops.lat, mta_stops.lon).min(), axis=1)

# %%
# Calculate the distance to wall street and midtown
units['dist_midtown']=units.apply(lambda row: calculate_distance(row.latitude, row.longitude, midtown['lat'], midtown['lon']), axis=1)
units['dist_wall_street']=units.apply(lambda row: calculate_distance(row.latitude, row.longitude, wall_street['lat'], wall_street['lon']), axis=1)

# %%
names = list(units.neighborhood.unique())

# %% [markdown]
# ### Remove extra columns that aren't useful for visualizing or the model

# %%
drop_columns = ['latitude', 'longitude', 'zipcode', 'unique_features', 'year_built', 'property_url', 'property_zipcode', 'unit_id', 'date_available', 'date_scraped', 'description']
units.drop(columns=drop_columns, inplace = True)
units.head()
# Out:
#     property_name    rent  beds  baths   sqft  fitness_center  \
# 0  The Brooklyner  4060.0     1    1.0  684.0               1
# 1  The Brooklyner  5122.0     2    2.0  976.0               1
# 2  The Brooklyner  4349.0     1    1.0  618.0               1
# 3  The Brooklyner  5195.0     2    2.0  976.0               1
# 4  The Brooklyner  3997.0     1    1.0  618.0               1
#
#    air_conditioning  in_unit_washer_dryer  laundry_facilities  car_charging  \
# 0                 1                     1                   0             0
# 1                 1                     1                   0             0
# 2                 1                     1                   0             0
# 3                 1                     1                   0             0
# 4                 1                     1                   0             0
#
#    ...  garage  dogs_allowed  cats_allowed  income_restrictions   borough  \
# 0  ...       1             1             1                    0  Brooklyn
# 1  ...       1             1             1                    0  Brooklyn
# 2  ...       1             1             1                    0  Brooklyn
# 3  ...       1             1             1                    0  Brooklyn
# 4  ...       1             1             1                    0  Brooklyn
#
#    dishwasher  price/sqft  dist_transit dist_midtown  dist_wall_street
# 0           1    5.935673      0.026536     4.106145          1.634417
# 1           1    5.247951      0.026536     4.106145          1.634417
# 2           1    7.037217      0.026536     4.106145          1.634417
# 3           1    5.322746      0.026536     4.106145          1.634417
# 4           1    6.467638      0.026536     4.106145          1.634417
#
# [5 rows x 24 columns]

# %% [markdown]
# # Visualization

# %%
# Plot rent versus sqft for each bedroom size
g = sns.FacetGrid(units[units.beds<4], col='beds', col_wrap = 2, aspect = 2)
g.map(sns.regplot,'sqft','rent').set(title='Rent vs. SQFT')

# %%
# Add a price/sqft column that will be useful for visualization
units['price/sqft'] = units.rent / units.sqft

# %%
# Visualize the relationship between price/sqft and distance to MTA stops

def transit_distance_plot(borough: str, df):
    # Filter for the specified borough
    df.loc[:,:] = df[df.loc[:,'borough'] == borough]
    
    # Create distance bins based on distance to MTA stops
    # Look at binning for every 1/8th of a mile
    bins = np.arange(0.00, 0.600000, 0.100000)
    labels = bins[1:]
    df.loc[:,'transit_dist_bin'] = pd.cut(df.loc[:,"dist_transit"], bins=bins, labels=labels)
    
    # Create the boxplots
    plt.figure()
    sns.boxplot(x = 'transit_dist_bin', y = 'price/sqft', data = df)
    plt.title(f'{borough}')
    plt.show()
    plt.close()

# %%
boroughs = ['Manhattan', 'Bronx', 'Queens', 'Brooklyn']
for borough in boroughs:
    transit_distance_plot(f'{borough}', units.copy())
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/pandas/io/formats/format.py:1429: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   for val, m in zip(values.ravel(), mask.ravel())
# /opt/anaconda3/lib/python3.9/site-packages/pandas/io/formats/format.py:1429: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   for val, m in zip(values.ravel(), mask.ravel())
# /opt/anaconda3/lib/python3.9/site-packages/pandas/io/formats/format.py:1429: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   for val, m in zip(values.ravel(), mask.ravel())
# /opt/anaconda3/lib/python3.9/site-packages/pandas/io/formats/format.py:1429: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   for val, m in zip(values.ravel(), mask.ravel())

# %% [markdown]
# Not surprisingly, the distance to an MTA stop in Manhattan doesn't have too much of a relationship with the price/sqft. There does seem to be a relationship within the other boroughs.

# %%
#plotting binary features
for i in units.columns[6:20]:
  plt.figure()
  sns.boxplot(x = i, y = 'price/sqft', data = units)
  plt.show()
  plt.close()

# %% [markdown]
# Car charging stations and income restrictions appear to have a very unbalanced data set. Both of these columns should be dropped as they will not contribute to the model.

# %%
# Drop income restrictions, car charging and price/sqft
units.drop(columns={'car_charging', 'income_restrictions', 'price/sqft'}, inplace=True)

# %%
corr_map = units.corr()

# Create a mask
mask = np.triu(np.ones_like(corr_map, dtype=bool))

f,ax = plt.subplots(figsize = (15,15))
sns.heatmap(corr_map, square = True, vmax = 0.7, cmap = 'RdBu', annot = True, mask = mask)
# Out:
# <AxesSubplot:>

# %% [markdown]
# The following updates to the dataset seem necessary to consolidate similar features:
# * Combine dogs and cats into a single pet category
# * Drop distance to wall street and keep distance to midtown

# %%
# Create new pets category
units['pets_allowed']=np.where((units.dogs_allowed == 1) | (units.cats_allowed == 1),
                               1,
                               0)

# Drop columns
units.drop(columns={'dist_wall_street', 'dogs_allowed', 'cats_allowed'}, inplace=True)

# %% [markdown]
# # Data processing

# %%
units.head()
# Out:
#     property_name    rent  beds  baths   sqft  fitness_center  \
# 0  The Brooklyner  4060.0     1    1.0  684.0               1
# 1  The Brooklyner  5122.0     2    2.0  976.0               1
# 2  The Brooklyner  4349.0     1    1.0  618.0               1
# 3  The Brooklyner  5195.0     2    2.0  976.0               1
# 4  The Brooklyner  3997.0     1    1.0  618.0               1
#
#    air_conditioning  in_unit_washer_dryer  laundry_facilities  roof  \
# 0                 1                     1                   0     0
# 1                 1                     1                   0     0
# 2                 1                     1                   0     0
# 3                 1                     1                   0     0
# 4                 1                     1                   0     0
#
#    concierge  pool  elevator  garage   borough  dishwasher  dist_transit  \
# 0          1     0         1       1  Brooklyn           1      0.026536
# 1          1     0         1       1  Brooklyn           1      0.026536
# 2          1     0         1       1  Brooklyn           1      0.026536
# 3          1     0         1       1  Brooklyn           1      0.026536
# 4          1     0         1       1  Brooklyn           1      0.026536
#
#    dist_midtown  pets_allowed
# 0      4.106145             1
# 1      4.106145             1
# 2      4.106145             1
# 3      4.106145             1
# 4      4.106145             1
